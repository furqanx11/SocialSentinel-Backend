# %% [markdown]
# # Social Sentinel Backend
# ## An engine developed to mitigate cyberbullying in mixed-code text.

# %%
# !pip install datasets
# !pip install sklearn

# %% [markdown]
# ## Testing our refined keywords on an open-source dataset
# [Dataset](https://huggingface.co/datasets/community-datasets/roman_urdu_hate_speech)

# %%
import re
from typing import List

def load_hatewords(filepath: str) -> set:
    with open(filepath, "r", encoding="utf-8") as file:
        lines = file.readlines()
        hatewords = set(word.strip().lower() for word in lines if word.strip())
    return hatewords

def detect_keywords(text: str, hatewords: set):
    text = text.lower()
    flagged_keywords = []

    for word in hatewords:
            pattern = re.sub(r"\\*", r".*", word)
            if re.search(pattern, text):
                flagged_keywords.append(word)
    return flagged_keywords

def is_cyberbullying(text: str, hatewords: set, threshold: int = 1):
    flagged_keywords = detect_keywords(text, hatewords)
    return len(flagged_keywords) >= threshold, flagged_keywords

# %%
from datasets import load_dataset
dataset = load_dataset("community-datasets/roman_urdu_hate_speech", "Coarse_Grained")

flagged_results = []
y_true = []
y_pred = []
hatewords = load_hatewords("/content/hatewords.txt")

for tweet, label in zip(dataset["train"]["tweet"], dataset["train"]["label"]):
    is_flagged, keywords = is_cyberbullying(tweet, hatewords, threshold=1)
    y_true.append(label)
    y_pred.append(int(is_flagged))
    flagged_results.append({
        "tweet": tweet,
        "is_cyberbullying": is_flagged,
        "flagged_keywords": keywords,
        "actual_label": label,
        "predicted_label" : int(is_flagged)
    })

for result in flagged_results:
    if result["is_cyberbullying"]:
        print(f"[FLAGGED] Cyberbullying detected in: '{result['tweet']}'")
        print(f"Flagged keywords: {result['flagged_keywords']}\n")
        print(f"Actual Label: {result['actual_label']}\n")
        print(f"Predicted Label: {result['predicted_label']}\n")
    else:
        print(f"[SAFE] No cyberbullying detected in: '{result['tweet']}'\n")
# Out:
# train-00000-of-00001.parquet:   0%|          | 0.00/525k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/147k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/58.5k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7208 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2002 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/800 [00:00<?, ? examples/s]
# Streaming output truncated to the last 5000 lines.
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'ye  saali mujh sy baat krna e chhor deti hai if i speak my stomach out so no i'm not lucky ✋'
# Flagged keywords: ['saali']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'chutiye halala ki upaz tu hai mein nahin isaliye tujhe zyada pata hoga'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'sabar tou ussi din seekh liya tha jis din ptcl lagwaya tha.'
#
# [FLAGGED] Cyberbullying detected in: 'khottay k bacho dallo haramkhoro kanjro nalaiko jahilo or pata nhi kiya kch niazi teri pen di sirii jahill kanjar yahodi loby k agent haramkhor badzat dalay baigairaton k sardar lakh di lanat tere munh tay itnay jahil ho k ghin ati hai tum jahiloon se badbo ati hai'
# Flagged keywords: ['haram', 'hot', 'kanjar', 'lanat', 'dala', 'dalay', 'yahodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'nihayat beghairt shaks hai yh lanti... hmyn sharm aati hai ky esy loog b hmary upper hukmarani krty rhy hain'
# Flagged keywords: ['lant', 'lanti', 'beghairt']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'yeh hei owaisi hijra, halala ki aulaad 🤣🤣🤣🤣🤣🤣🤣🤣'
# Flagged keywords: ['hijra', 'halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' bhai kuch aor posts b kro😀'
#
# [FLAGGED] Cyberbullying detected in: 'pti ko discuss karny k elawa ap ka aur kia kam hai najaiz khusrey'
# Flagged keywords: ['khusrey']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'koi facts naam ki b chez hoti hai ...  performance utha k dekh lain pata chal jaye ga kitna deserve karti thi sana meer 😁 '
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'wo to gaan se akhrot todd dete the'
# Flagged keywords: ['akhrot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' tu to rhene de bas'
#
# [FLAGGED] Cyberbullying detected in: 'zindagi mein koi kami hai lekin samajh nahi aata kya kami hai. gharwale kehte hain namaz dil kehta hai ishq lekin dimagh sirf kehta hai lpc'
# Flagged keywords: ['lpc']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' or dil krta h bnda sary kam chor kr un ka mehboob dhundh dy unko😏'
# Flagged keywords: ['chor']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bharwe apni maa ko bacha phle woh kitnon sy chudwa rhi h dekh jaa k randi k bache'
# Flagged keywords: ['bharwe', 'bacha', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bechari bhaunk bhaunk ke buddhi ho gayi. baal white ho gaye.'
# Flagged keywords: ['bhaunk']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' sahi baat ha😬'
#
# [SAFE] No cyberbullying detected in: ' it seems  bahi ke performance nay indirect taxation barhanay per majboor ker dia !'
#
# [FLAGGED] Cyberbullying detected in: 'i'm at box hill college of kuwait (bhck) in ahmdi'
# Flagged keywords: ['ahmdi']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'aby saali😂😂😂'
# Flagged keywords: ['saali']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' apne iman se bataen k ye jo march h ye haqooq k liye h ya be hayaie phelane k liye, ap is cheez ki aisi support kr rahe ho jaise k apne is main investment ki hui h, kia islami jahmoori pakistan is liye bana tha k equality k nam par quran aur sunnat ki khilaf warzi ki jae'
# Flagged keywords: ['equality']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'yup i like some of these songs or kuch aise songs ha in mie se jo miene nhi sunne i'll listen to it thnx'
#
# [FLAGGED] Cyberbullying detected in: ' demands aur slogans etc change ho jain to aurat march ko pura pakistan support kry ga'
# Flagged keywords: ['jain']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' wo to me hn hi😌'
#
# [FLAGGED] Cyberbullying detected in: 'tera  donky tu iqtdar deny k lye minty krta phr rha hy..per molna sb aisy iqdar per lanat bejhty hain yahodi agento...'
# Flagged keywords: ['lanat', 'yahodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'isse kehte hn akheer confidence.. idr hm hn (80% of boys) bc agr genuine kaam bhi ho to number nhi maang skte 😂'
# Flagged keywords: ['bc']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'kyun kya tmhari maa chod li mn ne?'
# Flagged keywords: ['maa chod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'randi salle look at yourself first'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '    agr fahad bhai ko ye anthem bakwas lagta to kabi nhi khety he don't tell a lie ok or would ek artist han to unhy zada pata ha to unhy patny ki zarorat nhi ha 🤨'
#
# [FLAGGED] Cyberbullying detected in: 'agar kya madarchod kya agar?! fuck off bhenchod fuckkk offf'
# Flagged keywords: ['madarchod', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'my entire neighborhood is making weird sounds bhenchod shaddi hai kya'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' tareen sab kam sy kam ham sy hi puch layt psl anthem kasy bnta ha    '
#
# [SAFE] No cyberbullying detected in: 'hain mtlb me waqai celeb hon jo interact ki tamanna thi?? 😳'
#
# [FLAGGED] Cyberbullying detected in: 'abhey ye saary teri bhai hain...abb tou teri kholny ka or mxa aye gatery bahioun ko b tou pta chaly kitni bari randi hai tu😘😘😘🤣'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'ary yeh dhandli nahi dhandla hai '
#
# [FLAGGED] Cyberbullying detected in: '1300 people commited suicide in sindh last 5 years dur fiteh munh  '
# Flagged keywords: ['fiteh munh']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'jo rooth jao ge to hum manyein ge❤️ tery sang jee rhy hain,jeety jyein ge🔥'
#
# [FLAGGED] Cyberbullying detected in: 'din mei 20-30 time call karke harras karte hai..'
# Flagged keywords: ['-']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'are bhenchod itni bheed thi ki nokia 3310 se vedio bna li. hahahahahahahahahahaahaha chutiye tum jahil ho to pkde jana lazim hai'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'teri maa ki phudi gashti k bachy kaafir hraami'
# Flagged keywords: ['phudi', 'gashti', 'kaafir']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' thk hen. sab'
#
# [SAFE] No cyberbullying detected in: 'koi samjh nahi ai😭😭😭mujhe pashtoo kis din aey ghi😭😭'
#
# [SAFE] No cyberbullying detected in: '  murad k mutabik waziristan me haqqani network wale moheb e watan loga ha. por se state terrorism ko dunya k samne expose kia'
#
# [SAFE] No cyberbullying detected in: 'pasand ki shai krne pe mujhe zinda darghoz kr diya us waqt mera jism aur trei marzi thi~aimma'
#
# [SAFE] No cyberbullying detected in: '  aisa aapne bola goli maaro saalon ko toh aaj yeh ho gaya please aapnek insaan ho dhumal ji bete ho aisa kisi ko nahi bolein jai mata ki'
#
# [FLAGGED] Cyberbullying detected in: 'afghanio ne tme hindu se bachaya,randi k aulaad tareekh paro tm wo ganda khoon ho,jo siko aour hindu ki rape se paida woe ho,tme kalima tho sikaya afghano ne,magar tmari gandi dna wai ranjeet sing wali a,randi k aulaad tm ne kah pana di,am pashtono ne di,apnay bio ko hera mandi'
# Flagged keywords: ['bacha', 'gand', 'randi', 'rape', 'hindu']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'khinzeer mullahs .. who cares..'
# Flagged keywords: ['khinzeer']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'han may me h kal sy parhna shuru kru ga 😂😂'
#
# [FLAGGED] Cyberbullying detected in: 'jis trah bao g or billu mori k lun pa char ka nachte rahay jamhuriat ka randi rona rotay rahe anjam dekh lea.ab     ka anjam pmln pppp or molana munafiq jesa hoga.saray bharway gaddar afghanion ki palet nasal ki manji thukne wali ha.'
# Flagged keywords: ['randi rona', 'munafiq', 'lun', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' abay yaar yeh twitter pe har teesra banda apni identity chupa ke q phirta hai'
# Flagged keywords: ['chupa']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' gauahar khan meri fav thi mera jo b fav hta win krta😍🙈'
#
# [SAFE] No cyberbullying detected in: ' kon a voooo?bta bhai ko.. abhi leta mein uski..class.🙄'
#
# [FLAGGED] Cyberbullying detected in: 'in main tm bhi shaamil ho harami ki olaad'
# Flagged keywords: ['haram', 'harami']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'mukesh aap b sach nen kehty...kya ye sab august 2018 sy ho rha ha...us sy pehly 'sab acha' tha?'
#
# [FLAGGED] Cyberbullying detected in: ' meri lines chori kee ja rahee hain😂😂'
# Flagged keywords: ['chor']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod what a goal!'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'tum bhi lagalo maza aayega. 😂😂'
#
# [SAFE] No cyberbullying detected in: ' kronologi di ptik tum  '
#
# [SAFE] No cyberbullying detected in: ' 🖐ha aise logon pe shayad ye marna bhool chuke hai.allah aise logon ko lawaras mot de .ameen'
#
# [FLAGGED] Cyberbullying detected in: 'wo bc kanjar haijra hy'
# Flagged keywords: ['bc', 'kanjar']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'pehle america jaiga ue begairaat musliman kehlwane kai laiq nh pehle he logh kehty h eske bary me ye yahoodi hai'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' wesay main ny dekhi thi ek asad wali tweet..🙄'
#
# [FLAGGED] Cyberbullying detected in: 'if you really 'respect' women then why didn't you stop halala system?'
# Flagged keywords: ['halala']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'ahmed niazi khottay ka puttar khachar nikhato nikamaa chooor yahodi lobby ka agent'
# Flagged keywords: ['hot', 'yahodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' ary kehny ka mtlb bht umdaa tha👏'
#
# [FLAGGED] Cyberbullying detected in: 'niazi yahoodi agent he'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: '😂😂puree harami'
# Flagged keywords: ['haram', 'harami']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'yaar such a jealous soul u r... allah se dua karenge jissey aap pyaar kare wo bhi aapko na mile... jo dusro ke pyaar se khush na ho usey zindagi me pyaar milneka koi hak nhi and when i am typing this msg everyone around me say amen'
#
# [FLAGGED] Cyberbullying detected in: 'randi ki bachi qismat! maa ki lauri ny ghar jana bhi mushkil kardia'
# Flagged keywords: ['bachi', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'lul bukhari ye tum nahe tumaray yahoodi or hindu thuku bol rahay hain jin ko army sey bahot hi zeda takleef hai...🖕'
# Flagged keywords: ['hot', 'yahoodi', 'hindu']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' jao menay baat ni karni🥺'
#
# [SAFE] No cyberbullying detected in: 'yeh gussa trend waly din nikaly ga ab💪💪💪💪💪💪'
#
# [FLAGGED] Cyberbullying detected in: '  sach bhi hota tou kon sa kar lyni thi 🤣'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'mai apke liye faroot mai kya laoun'
#
# [SAFE] No cyberbullying detected in: 'nobdy hates me. ye mera whem e shadeed ay'
#
# [FLAGGED] Cyberbullying detected in: 'khud to tum dono  r  besharam r by haya ho, gandi naali me paida hoi ho dono, r idar oron py b kecharr ochal rahi hon, beghairtoon, kash k qandeel baloch ki jaga koi tum dono ko shoot kar deta, 😡'
# Flagged keywords: ['haram', 'qandeel', 'beghairt', 'beghairto', 'gand']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' me 2. mere andar b ak larka hai. ye toh fake account hai.'
#
# [FLAGGED] Cyberbullying detected in: 'pakistan wo molk hy jo kuta ban kar hadi ki talash k liye 5 sall tak ek kute ko betha deta hy aur phir bhokta hy jub tak uski wafadari uon yahodi kuton sa hy lant'
# Flagged keywords: ['lant', 'kuta', 'kute', 'yahodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhen chod itna bada admi ronnie screwala direct bol diya manipulation ki haad paar kar diya inn logo ne.. nakli stardom bachoo'
# Flagged keywords: ['bhen chod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' kal me ny theek tweet kia na 😂'
#
# [FLAGGED] Cyberbullying detected in: 'ha bhenchod sale jnu itna acha h to waha se sab wannabe social activist/jehadi kyu nikal rahe h aur kabhi koi kuch bana h waha ka koi student ?'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bakwas na kar bharwe ye jo itni pakistani aurtein tv presenter aur anchor hain ye dikhai nahi deta choti soch wale'
# Flagged keywords: ['bharwe', 'hot', 'chor', 'chot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'q pakistan ka malik hai kotta ganju qoom ka paysa ta konsa apni jeb say laga raha wayse b pakistan ko kangal krdya hai allah aska jahaz tabah kry upar ta k zameen ayse hanzir k nahust say bachy rundi '
# Flagged keywords: ['rundi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt : selected azam, qadyani and yahoodi labi ka mustarka mohra " imran khan "'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt : kisi ko bhulnay k liye ussay yaad karna parta hai. aur idhr bhenchod yaad hi ati rehti hai bus'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' hae baddua to na do😀'
#
# [FLAGGED] Cyberbullying detected in: 'akhrot bhai aap ke pass kua saboot hey ke nawaz chor hey plz aap bhe kisi per ilzam na lagai'
# Flagged keywords: ['chor', 'akhrot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '   abhi abhi neo news se suna k cabinet ny pm ki pay increase kr d hy? kia yh such ha?'
#
# [FLAGGED] Cyberbullying detected in: 'rt : hum he ahmaq thay jo tere mazhab ka na socha  tujhe chorna tha, firqe ka bahana ban gya'
# Flagged keywords: ['chor', 'ahmaq']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'muh mei daant nahi gand se akhrot todega be?'
# Flagged keywords: ['gand', 'akhrot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'pehaly mei bohat khush thi phir mjhy #pyar hogya😣'
#
# [FLAGGED] Cyberbullying detected in: 'why we should consider gau muter slogan as insult. a beggar or hijra if not get bheek does same. a gunda or mawalli does same. does that effect any one. hell noo  so let paki bark. we know better, what we are.'
# Flagged keywords: ['hijra']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' 🤣🤣😂😂😂.mahi yeh tu hai na 😜'
#
# [FLAGGED] Cyberbullying detected in: 'saw bloodywood performance at wacken, it was so good to germans embracing the indian twist and dancing on it, unlike elitist indians who have problem with every fuckin thing and later crying their ass "scene kharab hogaya" bhenchod scene nahi tera dimag kharab hai.'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'jan allah ko dani ha per saboot court ko nahi dany is jumly k bad b aap jasy educated log na many to allah he hafiz app logu ka.'
#
# [SAFE] No cyberbullying detected in: 'fasla rakain bad mein ap kehty hn mein apny ghar walon ki marzi say shadi krni ha'
#
# [FLAGGED] Cyberbullying detected in: '  uus kamine ne koi prophecy puri nhi ki. tum log bas quran ki apne dil k mitabiq tafseer kar kar k uss marduud ko nabi sabit karne ki koshish karte ho.. jo hadees kehti hai k mahdi hi eesa hai wo bohat hi zaeef rivayat hai. marduud mirza  ne iss rivayat ko use kia jo hai hi galat'
# Flagged keywords: ['kamine']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' jese dil ki ankhon aor kanon pr pardy par gae han… muje laga hay koi aseeb hay😀'
#
# [FLAGGED] Cyberbullying detected in: 'yahoodi ko hitler ne chora or general ne in jaajoon ko chor k dhkya k ye kai hain.😂'
# Flagged keywords: ['yahoodi', 'chor', 'chora']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'teekaa to lga doon sahab per hoorai'n nazar ayengi aapko😜 '
#
# [FLAGGED] Cyberbullying detected in: 'teri ma ki choot or pakistan ki ma ka bhosda bhag bhosdike pkmkb'
# Flagged keywords: ['choot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'nakhre maan baap hi uthatey hain baki sub dhokha dete hain'
# Flagged keywords: ['baap']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod a 4 year old kid got raped by a janitor and a security guard during school time'
# Flagged keywords: ['bhenchod', 'chod', 'rape', 'raped']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'agar ap lahore se nh hain toh apka koi haq nh hai blogger bannay ka... chewtiye insan sharam ani chahea tumhe. socha b kese tumne bharwe'
# Flagged keywords: ['haram', 'bharwe']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt : fuddu log bhenchod'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' apni post per pakistani k comment ko bhe read kr leya kr...tujhe patta chale teri okaat ha kya...'
#
# [SAFE] No cyberbullying detected in: '  mein ny mlny na mlny ki bat ni ki thi wsy bola k js sy muhbt ho zda allah us bndy ko usi k hatho torta ha or apny ghr ko khaali kr k makeen ho jta phr usi dil mn.'
#
# [FLAGGED] Cyberbullying detected in: 'apni shakal dekh charsi..'
# Flagged keywords: ['charsi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'iran shia mulk ha or ye munafik log han'
# Flagged keywords: ['shia', 'munafik']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bygyrat pakistan ko badnam kar k mazy kar haramzadi randi'
# Flagged keywords: ['haram', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'laanat ho assy beshram per.'
# Flagged keywords: ['laanat ho', 'laan', 'laanat']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'aby saalay😂😂😂'
# Flagged keywords: ['saalay']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'wtf is thisssss lineup bhenchod'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bc tmhen chora q unhon ny mein to ya pareshan hu gandy andy'
# Flagged keywords: ['bc', 'chor', 'gand', 'chora']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '  jaj sahib kal ap apni bhen beti ko salogan pakra kar march mai bhejna phr ap haq py faisla suna sako gy????'
#
# [SAFE] No cyberbullying detected in: 'london walo ko bula lain janab ek dafa'
#
# [FLAGGED] Cyberbullying detected in: ' idhr ae chori ni hota in sha allah'
# Flagged keywords: ['hot', 'chor']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'teri ma ka burr ko forest land bna denge bharwe...😂'
# Flagged keywords: ['bharwe']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt : officer hoke ye hottness upload krna burri bat ha😂'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'dumbo top 6 m connection ki wzah se pahuchi and she knows it well  jab kch pata ni h chup- hi reh bhaunk mat jada'
# Flagged keywords: ['bhaunk', '-']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'shrif family ka 1 or pol khol gya landan ka falts jo ka un ka motbik 2006 ma lia gya hn ohh 1992_93 sa un ka pass han'
# Flagged keywords: ['_']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'no one:  superstitious pakistanis: "black friday yahoodi saazish hai!"'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' aurat ka ehtram o atmad march . aj kal k daor main khushion ke rah main rukawat nahi banna chahiay .'
#
# [FLAGGED] Cyberbullying detected in: 'jaise tu randi ban gai h'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' kabhi kabhi mere dil mn ye khyaal aata hy main dunya main ayaa hun kiss liye'
#
# [FLAGGED] Cyberbullying detected in: 'jo bhi tu ney likha, most of it is correct.  lekin apney mulk ka bhi haal likh dekh pehley.  hagnay k lye toilets nahi hein, bhen chod oceans and lakes pey jaa k hagtay ho.  saaf peenay ka paani nahi hai. every minute, ek larki aur bachi ka india mein rape hota hai.'
# Flagged keywords: ['bachi', 'hot', 'bhen chod', 'chod', 'rape']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'yr main q sowa tu so ja bhabhi mary gi '
#
# [FLAGGED] Cyberbullying detected in: 'abay saalay! copy krte tm'
# Flagged keywords: ['saalay']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 

#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'sai ha mtlb reply nh ay ga 😅'
#
# [FLAGGED] Cyberbullying detected in: 'lol ap hmare muashray ko tabah krna chahti hain? ap shayd lahorism ka shikar hain. 🤭 baqi teams khailne ni ati kya. 😂 jeet uski hoti hai jo acha khailta hai, jiske muqaddar me jeet hoti hai. 😒😋'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'khoya hota houn jab teri yadoun mein  mein bhi aksar mein nahi hota ... '
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'muh se moongfali nahi toot thi aur gaand se akhrot todenge #porkistan 😂😂😂'
# Flagged keywords: ['gaand', 'akhrot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'ek aur sachi muhabat per drama hu'
#
# [FLAGGED] Cyberbullying detected in: 'iim joka k bharwe jaldi paise de delivery wale ko taki woh mera delivery de de bsdk'
# Flagged keywords: ['bharwe', 'bsdk']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: '   bank sare he 1 jese hote hen... but un ki product and services different ho sakti hen 😎'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'ahmdi is a non muslim biggest cheap religion ahmdi.'
# Flagged keywords: ['ahmdi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'hm mr jain gy yaqeen ni aata itna sasta ho ga'
# Flagged keywords: ['jain']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'sahi koyi randian ho jo kaho wo maan leti ho...asal mai tmhy koi frq nhi parta jo charhta hai tmhary oper wo yehi kehta hai es lye tmhy kutti kaho randi kaho tmhy koi farq nhi parta🎭🎭'
# Flagged keywords: ['kutti ka', 'randian', 'randi', 'kutti']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' harr jaga apni rundi roona ly kr ajaya kr koonii aonna zoye balochistan'
# Flagged keywords: ['balochi', 'rundi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'tu kyu apni maa chudwane aa jati hai... apne mulle ki apne ghar mein rakh ke chudwa le... randi'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'meri kal ki presentation aap prepare kar lo article bhi parh lo aur assignment bhi bana do phir🙄'
#
# [SAFE] No cyberbullying detected in: '  apna dm activate karain twitter per'
#
# [FLAGGED] Cyberbullying detected in: 'abey haramkhor pehle yah to bata de.. mein ek analyst hoon mera kya matlab hai iske pichhe konsi script kaam kar raha hai? tere jaise chutiya samajh rakha hai kya mujhe ki har baat pe ungli marunga par koi kaam dhang se nahi karunga.. last me wohi reservation'
# Flagged keywords: ['haram', 'chutiya']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'tu apni maa chudai se baaz ajao bhen k lory warna .. tera youtube nhi rhy gaaa??? firqawareyat phaila rha hy haramzady'
# Flagged keywords: ['haram', 'chudai', 'firqa']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'itni bhi kya khushi bhenchod kam awaaz mein gallan goodiyaan suno'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'koi nii palto gi jis din us din sahi😂'
#
# [FLAGGED] Cyberbullying detected in: 'tu chor raha ha tou khata ismey tere kya har shaks meray sath nibah bhi nhi sakta.'
# Flagged keywords: ['chor']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '  clr choose karna tha us k leye main ny whatsapp dedo wala choose keya 🌚🌚🤟'
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod wele ho? mtlb hd hai'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'rt : successfully blocked by "aap mery friends sy barh kr kch hein" 🌚'
#
# [SAFE] No cyberbullying detected in: '  pta ni kon allah ka naik bnda hai 😁🙊'
#
# [SAFE] No cyberbullying detected in: 'ye sirf uper uper k batyn ha😂😂😂🤭'
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod bharat ki tujhe itni fikar kyu ho rhi hei apne mulk ko to sambhal'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'ya han wo thumary aman ke baat karny waly aman pasand.shame on you 3rd class aurat'
#
# [SAFE] No cyberbullying detected in: 'aap bhi tou single hain aap ko pata hona chahiye 🙄'
#
# [FLAGGED] Cyberbullying detected in: 'manzoor kirlo _ mirasi de gori _ new best comedy video 2020 _ funny latifa'
# Flagged keywords: ['mirasi', '_']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'no dude. this is twitter. you don't get bios written in french here. instead, you get madarchod, bhenchod  here in bios.'
# Flagged keywords: ['madarchod', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'babu ji limit cross ker jatay hain baap honey ka yeh muqsed na dikhaya jay ky woh puray muhalay ko pereshan kerain'
# Flagged keywords: ['baap', 'kera']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'neend randi plis ajao'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'nahi bhole the tumhe 😭❤️'
#
# [SAFE] No cyberbullying detected in: ' na kr 😂😂🙄'
#
# [FLAGGED] Cyberbullying detected in: 'rt : tu hai kaun be ?? maine invite kiya tha kya tuze jo mere tl pe aake bhaunk rahi 🙄🙄'
# Flagged keywords: ['bhaunk']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'waooo so delicious tea 😋😋♥️❤️ made by mama   kon kon peena chahta?? #wednesdaythoughts'
#
# [SAFE] No cyberbullying detected in: ' happy birthday allah pak aap ko seht tandrusti wali lambi zindgi ata farmae aur aap ise tarah hansti muskraati rahen aameen '
#
# [FLAGGED] Cyberbullying detected in: 'okay, will respond you later on the same sir,  for the time being  sunn bhadwe  maa chudwa ke aand ke beez harami ke pille randdi ki aulaad saale haram jyada madarchod teri maaki chuut dalle, chudai khaane  just want to see ur reaction lodu😂  maa chudwale harami  cc: '
# Flagged keywords: ['haram', 'harami', 'madarchod', 'saale', 'chudai', 'randdi', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod. it will follow me till my grave.  who does that?  is se behter bhenchod 6-0 6-0 6-0 jeet jaao.'
# Flagged keywords: ['-', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' i want ki tujh jaisa chutiya age paida na ho desh mai 😂'
# Flagged keywords: ['chutiya']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'chalain aap kehte hain tau janay deti hoon😂 lekin agar ab is ne mazeed bakwas ki tau is ke level pe aa ke is ko seesha dikhana paray ga i think😁'
#
# [FLAGGED] Cyberbullying detected in: 'bc you’re so goddamn horny all the time'
# Flagged keywords: ['bc']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'yahoodi controlled media ha. lanat ha aise media or white terrorists pe.'
# Flagged keywords: ['yahoodi', 'lanat']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' raat corona nahi ab'
#
# [FLAGGED] Cyberbullying detected in: 'tu ja ke puch apni ammi se kiske halala ka beej hai tu..'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt : eating pancit canton alone is so 🥰 bc u know wala ka kacompetition hahhaaha'
# Flagged keywords: ['bc']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhai chod do oo dummy home minister hai poora uska hair cm ke paas hai'
# Flagged keywords: ['chod', 'bhai chod']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 
henchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' piar kisi k kàhny p ni ho skta'
#
# [SAFE] No cyberbullying detected in: 'azma k dekh lo'
#
# [FLAGGED] Cyberbullying detected in: 'welcome movie dialogue...paisa tera baap chod k gea tha ki teri maa...'
# Flagged keywords: ['baap', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'fasla rkhy phr kehti hai k garh walo ko dokha nhe dy skti :)  #trending'
#
# [SAFE] No cyberbullying detected in: 'mry sy nhi kry gi dekh ly to'
#
# [FLAGGED] Cyberbullying detected in: 'ye wo lady's he jinhe halala or roj naye naye mardo ka shok he'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'education pe ghussa agya tha bhenchod punjab mai knsa na hum log gobar waly hathon se khana khaty hn education nahi hai ajeeb chutiyapa hai yai'
# Flagged keywords: ['chutiya', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' kitna mal khilaya ry tum isko'
#
# [FLAGGED] Cyberbullying detected in: 'chup madarchod atankwadi buechodi randi sali kutiya harmai pilli bhn ki laudi'
# Flagged keywords: ['madarchod', 'kuti', 'randi', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' kisi tesray ki zarorat nhi hai..🤣🤣'
#
# [SAFE] No cyberbullying detected in: 'bhai sahb ,ye kis line main aagaye aap😂'
#
# [FLAGGED] Cyberbullying detected in: 'what do you do when you come across a hijra begging at traffic intersection?'
# Flagged keywords: ['hijra']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'aj kal k relationships se zyada mazboot toh akhrot hain'
# Flagged keywords: ['akhrot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'shame less nai ghatya ganda churra charsi bander ha ye'
# Flagged keywords: ['charsi', 'gand']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'and m not saying mards are nice... sab main khot hai.. koi doodh ka dhula hua nahe hai.. mujh main kudh main bht khot hain.. khudara 1 side pe criticize naw karo.. if mard is bura... aurat is clean???  har kisi ko bss mard main burayi nazar ati hai'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'you are an ahmadiya so you probably understand the mistreatment of hindus in pakistan.'
# Flagged keywords: ['ahmadiya', 'hindu']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'yes wo fahad bhai ki soch or sahi kha ha'
#
# [SAFE] No cyberbullying detected in: ' prr yr justin ny abhi tk follow nhi kia 😂'
#
# ...
#
# [FLAGGED] Cyberbullying detected in: 'rt : tum log randi rona roty reh jao gy or karachi trophy ly jay ga'
# Flagged keywords: ['randi rona', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' to fast ko face karna tha na ☹️☹️🥺🥺😥😂'
#
# [FLAGGED] Cyberbullying detected in: 'pata hoga tu baap badlaingay na'
# Flagged keywords: ['baap']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'you may have got a govt. job relaxing 3 hour lunch brake you know sbi and you know icici.  when a person becomes billionaire he runs family of lakhs of people. these are job generators not job seekers be thank ful. without reliance imagine mumbai metro?'
# Flagged keywords: ['lun']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'ager mumtaz qadiri ki terha qanoon hath me lena he he tu ja ki pm ik ko bhi koi marni ke lia chala jae ga   as our jaali molvis claim that he is a yahoodi.'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' retweet nhi karni na karo.. philosophy mat jharo..😒'
#
# [FLAGGED] Cyberbullying detected in: 'teri maa ki phudi hy. nawaz shareef ny kia jamaima ko choda tha jo eski waja sy juda hovy hn. teri jase randio ko chodta tha eswaja sy wo chali gai ti'
# Flagged keywords: ['phudi', 'choda', 'randi', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'the protest of charsi people of india'
# Flagged keywords: ['charsi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in

#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'hum ny ibadat dil sy ki thi jis ny chaha dil ko tora'
#
# [FLAGGED] Cyberbullying detected in: '1995 mein dr sb ne bta dia khan yahoodi agent hai'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'han hn to kha ha ap ko to lehaza tang na karyn'
#
# [FLAGGED] Cyberbullying detected in: 'i should've a bhenchod counter which will count the amount of times i've sad bhenchod'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' mujhy pata hai tumharay sath kiya hua hai..🙃'
#
# [FLAGGED] Cyberbullying detected in: 'bhai yahoodi bhi aik khuda per eeman rakhty hain jo hum muslims rakhty hain. kindly is baaat ka source pehly dhoond lain.'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' tary tu waraay neiyaray ho gaye 😂'
#
# [FLAGGED] Cyberbullying detected in: 'bhukla sala nalla charsi admi h'
# Flagged keywords: ['charsi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'no doubt you have never seen a mirror. chamche me he dekh le jo naye waley nikal k diye the tere karyakarta ne!'
# Flagged keywords: ['mc']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'tu bosdk cartoon network hi dekhta reh jayega..hum pok bhi le jayenge 🤣🤣'
# Flagged keywords: ['bosdk']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' inteha ke kameengi dekhaye hay bhai aap ne tu😕😕😕'
#
# [FLAGGED] Cyberbullying detected in: 'abuse and cursing won’t cut it for me..... hang nawaz, sons won’t give a shit.... they love only money.... ohhhh found the appropriate word. beghairat!'
# Flagged keywords: ['beghairat']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'or tum log halala ki paidaish ke shikarðÿ¤£ðÿ¤£ðÿ¤£'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'teri phudi ko aram nhi a sakta or aye b kesy bhai tery mar maw jain🤣🤣🤣🤣👙💵💵'
# Flagged keywords: ['jain', 'phudi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'tu bhenchod badmaash hai?'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'aurat ka paisa aurat ka paisa aur mard ka paisa bhi aurat ka paisa. bohat na insafi hai 😂'
#
# [FLAGGED] Cyberbullying detected in: 'sale chakke ka 1 flwr nhi or bate dekho. ja apni randi ma k sath jake dhanda kr nikal 😂'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '  khud kon c doodh ki dhuli hai logo ko sab pta hai kashmeera k bare mein'
#
# [SAFE] No cyberbullying detected in: 'rt : kitne vaade, kitni baatein baaki hain kitne din aur, kitni raatein baaki hain.'
#
# [SAFE] No cyberbullying detected in: 'both bolti ha yawwr☺️'
#
# [FLAGGED] Cyberbullying detected in: 'rt : hijra namard salman khan'
# Flagged keywords: ['hijra', 'namard']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'rt :   halala center khol raha hai'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'yaani aap ko husband sabzi lanay k liay chahiay'
#
# [SAFE] No cyberbullying detected in: 'sene sy tere sir ko lga k  sunti mn rhn nam apna🥰💕'
#
# [FLAGGED] Cyberbullying detected in: 'mana k sabar ka phal meetha hota hai but jitna sabar mene krlia hai mera phall sarrh chuka hoga 😂'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' hum yahan tumhari baat nhi kar rahay..😪'
#
# [FLAGGED] Cyberbullying detected in: 'salman bhai namard nahi hai ye randi ke canadians ki gaandh jal gayi hai jabi ye trend kar rahe hai ye.'
# Flagged keywords: ['gaand', 'namard', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'chal fosdi ke mohammad kabile wale ki halala ki aulad'
# Flagged keywords: ['halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'fir bhi, tumhari tarah america ya saudi arabia se bhikh to nhi maangte...  saale, saudi kutta, modi ke kahane pe saudi arabia ne tumhe kolalampur jaane se roka..ðÿ¤£ saale, halala ki paidaish, jo apni ma bahano ko china se ch**dne k liye lga diya ho, wo india se baat kar rha h..'
# Flagged keywords: ['saale', 'kutta', 'halala']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'didnt feel like is that song of cricket league or a bhngra for #shadi😡😕 marzi ha #asimazhar apna bhi yh krna tha..  #tayyarhain'
#
# [FLAGGED] Cyberbullying detected in: 'hoskta hy jaani, jaakey ulma ka fatwa sunlo youtube pe mene suna hy tbhi keh raha hun. rahi baat halala ki to ye ek haram cheez hy, this lines by dr. zakir naik.'
# Flagged keywords: ['haram', 'halala']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'sudia yahoodi bhai bhai'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bhenchod aewee tou bollywood itna mashoor nai hai. talent bc kutt kutt k bhara hua hai is mulk mein.'
# Flagged keywords: ['bc', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: ' kaya baat bai zindagi tu sirf inko hi apni aziz hy baki awam jain bhaar mein.'
# Flagged keywords: ['jain']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'aaja tjhe phir se maza dun'
#
# [FLAGGED] Cyberbullying detected in: 'sali randi hai tu bilkul sudhar nahi sakti'
# Flagged keywords: ['randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'aqal ke dushman ye tanqeed army par nahi army ko kharab karnay walon  par hai. kash mein mirasi hota kiun ke ye merey liay ahzaz hota lekin shukar hai toute nahi'
# Flagged keywords: ['mirasi', 'hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' aj k liye yhi bht hy allah maaf kry bht mushkil hy😂'
#
# [SAFE] No cyberbullying detected in: ' ab bqio ny kehna hmmy to pehla pta tha😂😂'
#
# [FLAGGED] Cyberbullying detected in: 'kaafir ki nasal'
# Flagged keywords: ['kaafir']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'yeh funny nahin bulkay sharam ki baat hai waisay hum news bhi fake khabron mein bohut agay hai sara k sara media hi chitrol k qabil hai'
# Flagged keywords: ['haram']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'i thought bcv was when fobs tryna type bhenchod'
# Flagged keywords: ['bc', 'bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: '   hahaha very funny tere baap ne bri tameez sikhaie ha tuje 😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂'
# Flagged keywords: ['baap']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: 'ek din tu na mile ga tera naam phir bhi rahega 😔 #psl5'
#
# [FLAGGED] Cyberbullying detected in: 'doub mar yahoodi kaan'
# Flagged keywords: ['yahoodi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'come on brain randi think of something funny please gashti'
# Flagged keywords: ['gashti', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' list m ni h... but feel atitude hua tha'
#
# [SAFE] No cyberbullying detected in: 'sarey bajwa k itihadi hain baqi khosh hon dey bahaney ney 😉'
#
# [SAFE] No cyberbullying detected in: 'rt : jo zakhm dikhtae nhae, wo dukhtae bht hain 😔'
#
# [FLAGGED] Cyberbullying detected in: ' han je han je bilkol bandi be soni 😍💯🌸 or dono be 😋👌😄😅wo sb sy best hota'
# Flagged keywords: ['hot']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'bharwe ka pata nahii lakin ramii buhot hote'
# Flagged keywords: ['bharwe', 'hot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' badi serious ho rhi ho kya baat hai.'
#
# [FLAGGED] Cyberbullying detected in: 'friend 1 : konsi uni join ki ? friend 2 : lumsu friend 1 : tere driver ka naam ni poocha  friend 2 : abbey saalay'
# Flagged keywords: ['saalay']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'teri maa rundi'
# Flagged keywords: ['rundi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: '  ye mat bolo warna aap prty win hai 😁'
#
# [FLAGGED] Cyberbullying detected in: 'lolz, whatsapp se bahar nikal akhrot and have pork chops in dubai'
# Flagged keywords: ['akhrot']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' dost wo nhi jo har waqat ap ki tareef kry'
#
# [FLAGGED] Cyberbullying detected in: 'rt : bhenchod 100 follow kru to 3 follow back dete hain wo bhi newbies'
# Flagged keywords: ['bhenchod', 'chod']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'wo yaqeenan bohat khush hote k bachun ki kamyabi baap ka fakhr hota hai..allah swt unki maghfirat frmaye ameen..aap ko apni kamyabi mubarak ho 🎉💖'
# Flagged keywords: ['hot', 'baap']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' chup karo aap jhoot nahi bolo'
#
# [FLAGGED] Cyberbullying detected in: 'period me chudai karne se koi nuksan to nahi'
# Flagged keywords: ['chudai']
#
# Actual Label: 1
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' afridi n jb 6ka mara tha kholi k reaction dakhne wala tha wohi bhi lgao n pic🤓'
#
# [FLAGGED] Cyberbullying detected in: 'randiyo se bhi nichle darze ki aurat,'
# Flagged keywords: ['randiyo', 'randi']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [SAFE] No cyberbullying detected in: ' mera jism meri marzi ya sub likh ker picture banana zaroor or twit kerna or hann apny papa ko bhai ko zaroor tag kerna'
#
# [FLAGGED] Cyberbullying detected in: ' apne kaam se kaaam zyada bhdwa mat ban bjp ke kutte'
# Flagged keywords: ['kutte']
#
# Actual Label: 0
#
# Predicted Label: 1
#
# [FLAGGED] Cyberbullying detected in: 'matlb bajwa imran yahodi ki tarha baykar jahil aor naehal insan ha'
# Flagged keywords: ['yahodi']
#
# Actual Label: 0
#
# Predicted Label: 1

# %% [markdown]
# # Testing keywords with scores.

# %%
import re
from typing import List, Dict
from datasets import load_dataset
import json

def load_keywords(filepath: str) -> Dict[str, float]:
    with open(filepath, "r", encoding="utf-8") as f:
        return json.load(f)

def detect_keywords(text: str, hatewords: set, use_regex: bool = False) -> List[str]:
    text = text.lower()
    flagged_keywords = []

    for word in hatewords:
        if word in text:
            flagged_keywords.append(word)

    return flagged_keywords

def is_cyberbullying(text: str, hatewords: set, threshold: int = 1, use_regex: bool = False) -> bool:
    flagged_keywords = detect_keywords(text, hatewords, use_regex)
    return len(flagged_keywords) >= threshold, flagged_keywords

def calculate_score(text: str, keywords_with_weights: Dict[str, float]) -> float:
    text = text.lower()
    total_score = 0.0
    for keyword, weight in keywords_with_weights.items():
        if keyword.lower() in text:
            total_score += weight
    return total_score

def update_fairness_score(user_scores: Dict[str, float], user: str, current_score: float) -> None:
    if user not in user_scores:
        user_scores[user] = 0
    user_scores[user] += current_score

def issue_warning(user_scores: Dict[str, float], warnings: Dict, user: str, threshold: float = 0.5) -> str:
    if user not in warnings:
        warnings[user] = 0
    if warnings[user] >= 2:
        return f"Warning: You have been temporarily blocked due to inappropriate behaviour and cant use any services until futher action."
    if user_scores[user] < threshold:
        return f"Warning: User {user} has a low fairness score ({user_scores[user]:.2f}). No actions taken."
    elif warnings[user] >= 2:
        return f"Warning: User {user} has exceeded the warning limit. And have been temporarily blocked."
    else:
        warnings[user] += 1
        return f"User {user} has been recieved a warning due to inappropriate behaviour (Score: {user_scores[user]:.2f}) (Total warnings: {warnings[user]})."

# %%
keywords_file = "/content/keywords.json"
keywords_with_weights = load_keywords(keywords_file)
user_scores = {}
warnings = {}

messages = [
    "Tum kitne ganda ho!",
    "Woh banda kitna kala hai.",
    "Yeh message bilkul safe hai.",
]
users = ["user1", "user2", "user3"]

for user, message in zip(users, messages):
    score = calculate_score(message, keywords_with_weights)
    update_fairness_score(user_scores, user, score)
    warning = issue_warning(user_scores, warnings, user)

    print(f"Message: {message}")
    print(f"User: {user}")
    print(f"Score: {score:.2f}")
    print(f"Fairness Score: {user_scores[user]:.2f}")
    print(f"{warning}\n")
# Out:
# Message: Tum kitne ganda ho!
# User: user1
# Score: 0.40
# Fairness Score: 0.40
# Warning: User user1 has a low fairness score (0.40). No actions taken.
#
# Message: Woh banda kitna kala hai.
# User: user2
# Score: 0.70
# Fairness Score: 0.70
# User user2 has been recieved a warning due to inappropriate behaviour (Score: 0.70) (Total warnings: 1).
#
# Message: Yeh message bilkul safe hai.
# User: user3
# Score: 0.00
# Fairness Score: 0.00
# Warning: User user3 has a low fairness score (0.00). No actions taken.

# %%
messages = [
        "Bhut besharam insan ho tum.",
    ]
for user, message in zip(users, messages):
    score = calculate_score(message, keywords_with_weights)
    update_fairness_score(user_scores, user, score)
    warning = issue_warning(user_scores, warnings, user)

    print(f"Message: {message}")
    print(f"User: {user}")
    print(f"Score: {score:.2f}")
    print(f"Fairness Score: {user_scores[user]:.2f}")
    print(f"{warning}\n")
# Out:
# Message: Bhut besharam insan ho tum.
# User: user1
# Score: 0.80
# Fairness Score: 1.20
# User user1 has been recieved a warning due to inappropriate behaviour (Score: 1.20) (Total warnings: 1).

# %%
messages = [
        "Behra hogaya hai kiya?",
    ]
for user, message in zip(users, messages):
    score = calculate_score(message, keywords_with_weights)
    update_fairness_score(user_scores, user, score)
    warning = issue_warning(user_scores, warnings, user)

    print(f"Message: {message}")
    print(f"User: {user}")
    print(f"Score: {score:.2f}")
    print(f"Fairness Score: {user_scores[user]:.2f}")
    print(f"{warning}\n")
# Out:
# Message: Behra hogaya hai kiya?
# User: user1
# Score: 0.30
# Fairness Score: 1.80
# Warning: You have been temporarily blocked due to inappropriate behaviour and cant use any services until futher action.

# %% [markdown]
# # Testing on custom message

# %%
messages = [
        "",
    ]
for user, message in zip(users, messages):
    score = calculate_score(message, keywords_with_weights)
    update_fairness_score(user_scores, user, score)
    warning = issue_warning(user_scores, warnings, user)

    print(f"Message: {message}")
    print(f"User: {user}")
    print(f"Score: {score:.2f}")
    print(f"Fairness Score: {user_scores[user]:.2f}")
    print(f"{warning}\n")
